# %%
import h5py
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
f = h5py.File('/reg/d/psdm/cxi/cxilr6716/scratch/cali_gai_cor_results/ALF_buf_random_split.h5','r')

# %%
f.keys()
# Out:
# [u'run118_0',
#  u'run118_1',
#  u'run119_0',
#  u'run119_1',
#  u'run119_2',
#  u'run119_3',
#  u'run122_0',
#  u'run122_1']

# %%
f['run118_0']['ave_cor_byChunk'].shape[1]
# Out:
# 2

# %%
x = f['run118_0']['ave_cor_byChunk'].value
e = f['run118_0']['err_byChunk'].value
cpsi=np.load('/reg/neh/home/qiaoshen/run16_notebooks/encodeZ400_cpsi.npy')

# %%
x.shape
e.shape
# Out:
# (36, 10, 326)

# %%
plt.errorbar(cpsi[0],x[0,1], yerr=e[0,1])
plt.errorbar(cpsi[0],x[0,3], yerr=e[0,3])
plt.ylim(-5e6,1e6)
# Out:
# (-5000000.0, 1000000.0)
