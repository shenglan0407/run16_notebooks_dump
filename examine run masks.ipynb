# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import h5py
import os

# %%
ls -lh /reg/d/psdm/cxi/cxilr6716/results/masks/
# Out:
# total 289M
# -rw-rw----+ 1 qiaoshen ps-data 2.9M Jun 14 14:01 basic_psana_mask.npy
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun 19 17:01 run101_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  8 03:00 run102_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun 19 14:25 run103_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  8 05:15 run105_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun 19 12:24 run106_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun 19 12:38 run107_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  8 04:06 run108_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  8 04:41 run109_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun 19 12:23 run110_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun 18 16:16 run111_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  7 16:38 run112_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  7 16:44 run114_masks.h5
# -rw-rw----+ 1 qiaoshen ps-data 8.7M Jun  8 03:50 run115_masks.h5
# ...

# %%
mask_dir='/reg/d/psdm/cxi/cxilr6716/results/masks/'

run=103
f=h5py.File(os.path.join(mask_dir,'run%d_masks.h5'%run),'r')
print f.keys()
# Out:
# [u'mask', u'negative_pixel_mask', u'psana_mask']

# %%
plt.imshow(f['mask'].value,aspect='auto')

# %%
f['mask']
# Out:
# <HDF5 dataset "mask": shape (1738, 1742), type "|b1">
